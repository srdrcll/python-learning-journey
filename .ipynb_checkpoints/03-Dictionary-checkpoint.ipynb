# %%
#key - value pairing

# %%
fruitList = ["banana","apple"]

# %%
calorieList =[100,150]

# %%
fruitList[0]
# Out:
# 'banana'

# %%
calorieList[0]
# Out:
# 100

# %%
fitnessDictionary = {"banana":100,"apple":150}

# %%
type(fitnessDictionary)
# Out:
# dict

# %%
#fitnessDictionary[0] index mantığı yok artık. hata verir.

# %%
fitnessDictionary ["banana"] #100 yazamazsın
# Out:
# 100

# %%
fitnessDictionary ["apple"] #150 yazamazsın
# Out:
# 150

# %%
fitnessDictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitnessDictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitnessDictionary.values())
# Out:
# dict_values

# %%
list(fitnessDictionary.values())
# Out:
# [100, 150]

# %%
fitnessDictionary
# Out:
# {'banana': 100, 'apple': 150}

# %%
fitnessDictionary["banana"] = 200

# %%
fitnessDictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitnessDictionary["melon"] = 300  #yeni eleman ekleme#

# %%
fitnessDictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
#fitnessDictionary["appl"]

# %%
fitnessDictionary.get("apple",0)
# Out:
# 150

# %%
fitnessDictionary.get("appl",0)
# Out:
# 0

# %%
myDictionary = {100:"a",200:"b",300:"c"}

# %%
myDictionary = {"key1":"value1","key2":"value2","key3":"value3"}

# %%
myDictionary["key1"]
# Out:
# 'value1'

# %%
myMixedDictionary = {"key1":100,"key2":3.14,"key3":[10,20,30]}

# %%
myMixedDictionary["key1"]
# Out:
# 100

# %%
myMixedDictionary["key2"]
# Out:
# 3.14

# %%
myMixedDictionary["key3"]
# Out:
# [10, 20, 30]

# %%
myMixedDictionary["key3"] [1]
# Out:
# 20

# %%
lastDictionary = {"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}

# %%
lastDictionary["k4"] ["b"]
# Out:
# 200

# %%
lastDictionary["k2"] [3]
# Out:
# 40
