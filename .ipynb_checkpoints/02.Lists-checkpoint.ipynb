# %%
myString = "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
#List veri yapısıdır. koleksiyon olarak geçer ve içinde birden fazla veriyi tutmak için oluşturulmuş bir yapıdır.

# %%
myString[0]
# Out:
# 'h'

# %%
#myString[0]= "a"

# %%
#inmutable değiştirilmez. tek bir karakteri değiştiremezsin ama tamamını değiştirisin.

# %%
myString = "serdar"

# %%
myString
# Out:
# 'serdar'

# %%
##LIST##

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList[0]
# Out:
# 10

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100

# %%
myList  #mutable değiştirilebilir.
# Out:
# [100, 20, 30]

# %%
myList[len(myList)-1]
# Out:
# 30

# %%
myList[-1]
# Out:
# 30

# %%
myList.append(79) #ekleme

# %%
myList
# Out:
# [1, 100, 20, 30, 80, 79]

# %%
myList.count(20)
# Out:
# 1

# %%
myList.index(80)
# Out:
# 4

# %%
myList.insert (0,1) #insert (kaçinci indexe kaydedilsin,ne eklensin)

# %%
myList
# Out:
# [1, 1, 100, 20, 30, 80, 79]

# %%
myList.pop() #SON ELAMANI CIKARIR
# Out:
# 79

# %%
myList
# Out:
# [1, 1, 100, 20, 30, 80]

# %%
myList.remove(20) #hangi elemanı çıkarmak istersen onu çıkar.

# %%
myList
# Out:
# [1, 1, 100, 30, 80]

# %%
myList.reverse() #tersine cevirir.

# %%
myList.sort() #sıralıyor.

# %%
myList
# Out:
# [1, 1, 30, 80, 100]

# %%
x = input("enter x")
# Out:
# enter x 10

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
#pythonda inputtan gelen her şey string olarak algılanır.

# %%
y = input("enter y:")
# Out:
# enter y: 20

# %%
y
# Out:
# '20'

# %%
z = input("enter z:")
# Out:
# enter z: 30

# %%
inputList = []

# %%
inputList
# Out:
# []

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[1]
# Out:
# '20'

# %%
inputList[1]*2
# Out:
# '2020'

# %%
type(inputList[1])
# Out:
# str

# %%
## Veri Tipi Dönüştürme ##

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "python"

# %%
# int(myString) çeviremez
# float(myString) çeviremez

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1])*2
# Out:
# 40

# %%
nameList =["serdar","ahmet","mehmet"]

# %%
type(nameList)
# Out:
# list

# %%
floatList = [3.14,2.50,71.56]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["serdar",100,3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 *2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
#list1 / 5   MÜMKÜN DEĞİL

# %%
mixedList
# Out:
# ['serdar', 100, 3.14]

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[2])
# Out:
# float

# %%
#nestedList iç içe geçmiş listeler

# %%
myNestedList = [10,20,3.14,"serdar",[1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[3]
# Out:
# 'serdar'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
type(myNestedList[4])
# Out:
# list

# %%
x = myNestedList[0]

# %%
x
# Out:
# 10

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'serdar', [1, 2, 3]]

# %%
myNestedList[4] [1]
# Out:
# 2

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2][1]
# Out:
# 'd'

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList [::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList [2::]
# Out:
# [30, 40, 50, 60, 70]

# %%
firstList [:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList [::2]
# Out:
# [10, 30, 50, 70]

# %%
firstList [1:6:2]
# Out:
# [20, 40, 60]
