# %%
#unique elements, unordered

# %%
myList = [10,20,30,10,20,40,10,20,40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,10,20,40,10,20,40}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
# index mantığı yok yani mySet[0] yapamayız.

# %%
mySet2 = {30,40,50,60,70}

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2
# Out:
# {30, 40, 50, 60, 70}

# %%
#union birlestirme

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
#intersection kesişim

# %%
mySet.intersection(mySet2)
# Out:
# {30, 40, 50}

# %%
###

# %%
countryList = ["de","fr","tr","fr","tr","tr","de","nl","de","tr"]

# %%
set(countryList) #satış yaptığımız ülkeler
# Out:
# {'de', 'fr', 'nl', 'tr'}

# %%
len(set(countryList)) #kaç ülkeye satış yapmısız
# Out:
# 4

# %%
###########

# %%
emptyList = []

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptySet = {}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set() #boş set oluşturma. diğerlerinde de olur emptyList = list(), emptyDict = dict()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(10)
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)

# %%
emptySet
# Out:
# {10, 20, 30}
