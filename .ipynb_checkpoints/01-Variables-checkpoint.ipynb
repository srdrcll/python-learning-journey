# %%
age = 50

# %%
age * 5
# Out:
# 250

# %%
age / 3
# Out:
# 16.666666666666668

# %%
# data type

# %%
type(10)
# Out:
# int

# %%
type(age * 5)
# Out:
# int

# %%
type (-1000)
# Out:
# int

# %%
type(age/2)
# Out:
# float

# %%
#float - floating point ondalıklı sayılar

# %%
#int - integer tam sayı

# %%
myFloat = 1.434334

# %%
type(myFloat)
# Out:
# float

# %%
#camelCase #myFloat
#snake_case #my_float

# %%
40/4
# Out:
# 10.0

# %%
type(40/4)
# Out:
# float

# %%
# bölünmede sonuç float çıkıyor

# %%
type(75-34)
# Out:
# int

# %%
type(7.5 % 3)
# Out:
# float

# %%
type(7.5 - 3)
# Out:
# float

# %%
10 % 3  #remainder. kalanı bulma
# Out:
# 1

# %%
##STRINGS##

# %%
"hello world!"
# Out:
# 'hello world!'

# %%
print ("hello python")
# Out:
# hello python

# %%
name = "Serdar"

# %%
type(name)
# Out:
# str

# %%
name = "serdar cil"

# %%
name.capitalize()  #sondaki () bu fonk. çalıştır demek eklemeseydik fonk. kodunu gösterecekti
# Out:
# 'Serdar cil'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
name
# Out:
# 'serdar cil'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("z")
# Out:
# 0

# %%
name.upper()
# Out:
# 'SERDAR CIL'

# %%
x = 10
y = 5

# %%
x + y
# Out:
# 15

# %%
z = x + y

# %%
z
# Out:
# 15

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'SERDAR CIL'

# %%
name
# Out:
# 'serdar cil'

# %%
print(name.upper())
# Out:
# SERDAR CIL

# %%
help(name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
len(name) #length kaç karakter oldugunu soyler. boşlukta bir karakter
# Out:
# 10

# %%
print("serdar cil")
# Out:
# serdar cil

# %%
print ("serdar \n cil")
# Out:
# serdar
#  cil

# %%
# \n --> new line
# \t -- tab  1 tablik boşluk

# %%
print ("serdar \t cil")
# Out:
# serdar 	 cil

# %%
 #INDEX

# %%
myString = "hello python"

# %%
myString [4]
# Out:
# 'o'

# %%
myString [0]
# Out:
# 'h'

# %%
myString [1]
# Out:
# 'e'

# %%
#myString [12] string index out of range

# %%
myString = "Serdar Cil"

# %%
myString[0]
# Out:
# 'S'

# %%
len(myString)
# Out:
# 10

# %%
len(myString) - 1 #bize index sayısını verir.
# Out:
# 9

# %%
myString[-1] #pythonda -1 yazarsak. son karakteri verir
# Out:
# 'l'

# %%
myString[-2] #pythonda -2 yazarsak. sondan bir önceki karakteri verir
# Out:
# 'i'

# %%
####

# %%
barcode = "ABCDE123123982"

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode[1]
# Out:
# 'B'

# %%
barcode[2]
# Out:
# 'C'

# %%
"A" + "B"
# Out:
# 'AB'

# %%
name = "serdar"

# %%
surname = "cil"

# %%
fullname = name + " " + surname

# %%
fullname
# Out:
# 'serdar cil'

# %%
fullname * 5
# Out:
# 'serdar cilserdar cilserdar cilserdar cilserdar cil'

# %%
100* "a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[0] + barcode [1] + barcode [2]
# Out:
# 'ABC'

# %%
#slicing  starting index, stopping index, stepping size

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
#barcode[starting index:stopping index:stepping size]

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[:3:] #3. indexi almaz
# Out:
# 'ABC'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[::-1] # -1 yazarsan ters çevirir.
# Out:
# '289321321EDCBA'

# %%
name = "serdar cil"

# %%
name.index("i") #boşluğu da saydı.
# Out:
# 8

# %%
name.split()
# Out:
# ['serdar', 'cil']

# %%
type(name.split())
# Out:
# list
