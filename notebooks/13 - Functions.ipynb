# %%
#method vs. function

# %%
myName = "serdar"

# %%
myName.upper()
# Out:
# 'SERDAR'

# %%
myName
# Out:
# 'serdar'

# %%
myNameUpper = myName.upper()

# %%
myNameUpper
# Out:
# 'SERDAR'

# %%
myName
# Out:
# 'serdar'

# %%
help(myName.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
# functions  kod bloklarıdr. kodu düzenli yazmaya olanak tanır. sonradan tekrar kullanılabilir
#girdi alabilir cıktı uretebilir

# %%
def helloPython():
    print("hello")
    print("python")

# %%
helloPython
# Out:
# <function __main__.helloPython()>

# %%
helloPython()
# Out:
# hello
# python

# %%
#input

# %%
def helloName(name):
    print ("hello")
    print (name)

# %%
helloName()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 helloName()
#
# TypeError: helloName() missing 1 required positional argument: 'name'

# %%
helloName("serdar")
# Out:
# hello
# serdar

# %%
helloName("python")
# Out:
# hello
# python

# %%
def sumExample(num1,num2):
    print(num1+num2)

# %%
sumExample(10,5)
# Out:
# 15

# %%
def sumExample(num1,num2):
    num3= num1+num2
    print(num3)

# %%
sumExample(20,8)
# Out:
# 28

# %%
def helloSurname (surname="cil"):
    print("hello")
    print(surname)

# %%
helloSurname("sam")
# Out:
# hello
# sam

# %%
helloSurname()
# Out:
# hello
# cil

# %%
#return

# %%
def summation(num1,num2,num3):
    print(num1+num2+num3)

# %%
summation(10,2,8)
# Out:
# 20

# %%
x =summation(10,2,8)
# Out:
# 20

# %%
x

# %%
print(x)
# Out:
# None

# %%
type(x)
# Out:
# NoneType

# %%
def returnSummation(num1,num2,num3):
    return(num1+num2+num3)

# %%
returnSummation(10,2,8)
# Out:
# 20

# %%
x = returnSummation(10,2,8)

# %%
x
# Out:
# 20

# %%
def returnSummation(num1,num2,num3):
    result = num1+num2+num3
    print(result)
    return (result)

# %%
x = returnSummation(10,2,8)
# Out:
# 20

# %%
x
# Out:
# 20

# %%
def controlStrings(s):
    if s[0] == "a":
        print("a")

# %%
controlStrings("atlas")
# Out:
# a

# %%
controlStrings("ahmet")
# Out:
# a

# %%
controlStrings("Serdar")

# %%
#args, kwargs

# %%
def argsSum(*args):
    return sum(args)

# %%
argsSum(10,20,30,40,50,60)
# Out:
# 210

# %%
def argsExample(*args):
    print(args)

# %%
argsExample(10,20,30,40,50,60)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
def kwargsExample(**kwargs):
    print(kwargs)

# %%
kwargsExample(apple=100,banana=150,melon=200)
# Out:
# {'apple': 100, 'banana': 150, 'melon': 200}

# %%
def kwargsExample2(**kwargs):
    if "apple" in kwargs:
        print("appleee")
    else:
        print(":(")

# %%
kwargsExample2(apple=10,banana=15)
# Out:
# appleee

# %%
kwargsExample2(banana=15)
# Out:
# :(
