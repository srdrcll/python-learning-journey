# %%
# %%writefile myfile.txt
# test1
# test2
# test3
# Out:
# Writing myfile.txt

# %%
myFile= open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myFile.read()
# Out:
# ''

# %%
myFile.seek(0)
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myFile.close()

# %%
##### with

# %%
with open("myfile.txt") as myFile:
    myContent = myFile.read()

# %%
myContent
# Out:
# 'test1\ntest2\ntest3\n'

# %%
with open("myfile.txt",mode="w") as myNewFile:
    myNewFile.write("test4")

# %%
myNewFile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='w' encoding='UTF-8'>

# %%
with open("myfile.txt",mode="r") as myNewFile2:
    myContent2 = myNewFile2.read()

# %%
myContent2
# Out:
# 'test4'

# %%
# w- write r- read  a- append

# %%
with open("myfile.txt",mode="a") as myNewFile3:
    myNewFile3.write("test5")

# %%
with open("myfile.txt",mode="r") as myNewFile4:
    myContent4 = myNewFile4.read()

# %%
myContent4
# Out:
# 'test4test5'
