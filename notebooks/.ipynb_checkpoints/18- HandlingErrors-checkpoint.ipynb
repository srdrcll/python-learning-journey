# %%
age = input("enter age: ")
# Out:
# enter age:  35

# %%
age
# Out:
# '35'

# %%
int(age)*2
# Out:
# 70

# %%
age = input("enter age: ")
# Out:
# enter age:  atil

# %%
age
# Out:
# 'atil'

# %%
# try except

# %%
try: 
    myAge = int(input("enter age: "))
    print(myAge*2)
except ValueError:
    print("enter your age!")
# Out:
# enter age:  35
# 70

# %%
try: 
    myAge = int(input("enter age: "))
    print(myAge*2)
except ValueError:
    print("enter your age!")
# Out:
# enter age:  atil
# enter your age!

# %%
#while True:
    #try: 
        #myAge = int(input("enter age: "))
        #print(myAge*2)
        #break
    #except ValueError:
        #print("enter your age!")

# %%
while True:
    try: 
        myAge = int(input("enter age: "))
        print(myAge*2)
        break
    except ValueError:
        print("enter your age!")
    else:
        print("else executed")
    finally:
        print("finally")
