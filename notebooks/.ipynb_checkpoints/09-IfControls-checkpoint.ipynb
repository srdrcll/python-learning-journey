# %%
x=5 
y=2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
y=5

# %%
x >=y
# Out:
# True

# %%
x=10

# %%
y=8

# %%
x=y

# %%
x
# Out:
# 8

# %%
y
# Out:
# 8

# %%
x=10

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
2 > 1 or 3 < 2
# Out:
# True

# %%
1 > 2 or 3 < 2
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30] #içinde 10 var mı
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
5 in [10,20,30]
# Out:
# False

# %%
10 in {10,20,30}
# Out:
# True

# %%
# myDictionary = {"a":10,"b":20,"c":30}
#10 in myDictionary yapamayız ama
#10 in myDictionary.values() yapabiliriz 
#veya
#"b" in myDictionary.keys() yapabiliriz.

# %%
10 in (10,20,30)
# Out:
# True

# %% [markdown]
# IF CONTROLS

# %%
if 3 > 2:
    print("serdar")
    print("3 2 1 ")
# Out:
# serdar
# 3 2 1

# %%
x = 4

# %%
y = 4

# %%
if x>y:
    print("x is greater")
elif x==y:
    print("x is y")
else:
    print("y is greater")
# Out:
# x is y

# %%
mySuperHero = input("enter superhero")
# Out:
# enter superhero Batman

# %%
if mySuperHero == "Batman":
    print("Bruce Wayne")
elif mySuperhero == "Superman":
    print("Kent Clark")
elif mySuperHero == "Iron Man":
    print("Tony Stark")
elif mySuperHero == "Spider Man":
    print ("Peter Parker")
else:
    print(":(")
# Out:
# Bruce Wayne

# %%
a=10
b=15
c=20

# %%
if a > b or b < c:
    print("Superman")
elif a < b or b > c:
    print("Batman")
else:
    print("Aquaman")
# Out:
# Superman

# %%
myAge = 100

# %%
if myAge <=18:
    print("age <= 18")
elif myAge > 18 and myAge <= 30:
    print ("18-age-30")
elif myAge > 30 and myAge <= 40:
    print("30-age-40")
else:
    print ("age >40")
# Out:
# age >40

# %%
mySuperHero = input("enter superhero:")
# Out:
# enter superhero: Iron Man

# %%
MySuperHeroList = ["Spider Man","Iron Man","Thor","Black Widow"]

# %%
if mySuperHero in MySuperHeroList:
    print(":)")
else:
    print (":(")
# Out:
# :)

# %%
isDead = False

# %%
if isDead == True:
    print("character is dead")
else:
    print("character is not dead")
# Out:
# character is not dead

# %%
if isDead:
    print("character is dead")
else:
    print("character is not dead")
# Out:
# character is not dead

# %%
if not isDead:
    print("character is not dead")
# Out:
# character is not dead

# %%
myString = "Hello World!"

# %%
if myString == "Hello World!":
    print("equal")
# Out:
# equal

# %%
if "Hello" in myString:
    print ("true")
else:
    print("false")
# Out:
# true

# %%
myList = [1,2,3,4,5]

# %%
if 2 in myList:
    print("true")
else:
    print("false")
# Out:
# true

# %%
myDictionary = {"k1":100,"k2":200,"k3":300}

# %%
if 200 in myDictionary.values():
    print("true")
else:
    print("false")
# Out:
# true
