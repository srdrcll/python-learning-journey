# %%
def divideNumber(number):
    return number / 2

# %%
divideNumber(20)
# Out:
# 10.0

# %%
myList = [3,5,7,10,20,30]

# %%
myResultList = []
for num in myList:
    myResultList.append(divideNumber(num))
print(myResultList)
# Out:
# [1.5, 2.5, 3.5, 5.0, 10.0, 15.0]

# %%
#MAP bir listeyi veya koleksiyonu alıp ona işlemler uygulayıp farklı halini yeni liste veya koleksiyona ekler

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(function, iterable, /, *iterables)
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
map(divideNumber,myList)

# %%
list(map(divideNumber,myList))
# Out:
# [1.5, 2.5, 3.5, 5.0, 10.0, 15.0]

# %%
def controlString(string):
    return "Atil" in string

# %%
controlString("Atil Samancioglu")
# Out:
# True

# %%
controlString("Samancioglu")
# Out:
# False

# %%
myStringList = ["Atil","Atil Samancioglu","Samancioglu","Atlas"]

# %%
list(map(controlString,myStringList))
# Out:
# [True, True, False, False]

# %%
#FILTER

# %%
list(filter(controlString,myStringList))
# Out:
# ['Atil', 'Atil Samancioglu']

# %%
#LAMBDA

# %%
multiplyLambda = lambda num : num*3

# %%
type(multiplyLambda)
# Out:
# function

# %%
multiplyLambda(20)
# Out:
# 60

# %%
result = multiplyLambda(10)

# %%
result
# Out:
# 30

# %%
numList = [10,20,30,40,50]

# %%
list(map(lambda num:num/4,numList))
# Out:
# [2.5, 5.0, 7.5, 10.0, 12.5]

# %%
##### SCOPE

# %%
x = 20 
def multiply(num):
    x = 5
    return num*x

# %%
multiply(10)
# Out:
# 50

# %%
print(x)
# Out:
# 20

# %%
x = 20 
def multiply(num):
    x = 5
    return num*x
x=10

# %%
x
# Out:
# 10

# %%
multiply(3)
# Out:
# 15

# %%
x = 20 
def multiply(num):
    return num*x

# %%
multiply(10)
# Out:
# 200

# %%
#LEGB LOCAL ENCLOSING GLOBAL BUILT-IN

# %%
#Global
myString = "Atil"

def myFunction():
    #Enclosing
    myString= "Atil 2"
    print(myString)

def myFunction2():
    #Local
    myString = "Atil 3"
    print(myString)

myFunction2()
# Out:
# Atil 3

# %%
myString
# Out:
# 'Atil'

# %%
myFunction()
# Out:
# Atil 2

# %%
###

# %%
def test1():
    myVariable =10
    print(myVariable*2)

# %%
def test2():
    print(myVariable*3)

# %%
#test2()  myVariable değeri test2 kapsamında olmadığı için hata verecektir.

# %%
##

# %%
y = 10 
def newFunction(y):
    print(y)
    y=5
    print(y)
    return y

# %%
newFunction(10)
# Out:
# 10
# 5
# 5

# %%
y
# Out:
# 10

# %%
y = 10
def changeY():
    global y
    y=5
    print(y)

# %%
changeY()
# Out:
# 5

# %%
y
# Out:
# 5
